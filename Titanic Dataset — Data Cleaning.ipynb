# %% [markdown]
#  🧹Titanic Dataset — Data Cleaning & Feature Engineering
#
#  Name: B. Manohar
#
# Phone Number: 8074386315
#
# Domain: AIML

# %%
#Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load Titanic dataset
df = sns.load_dataset('titanic')

# Display first few rows
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Overview of dataset
df.info()

# Summary statistics
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
# ...

# %%
# Count missing values
df.isnull().sum()

# Fill 'age' with median
df['age'].fillna(df['age'].median(), inplace=True)

# Fill 'embarked' with mode
df['embarked'].fillna(df['embarked'].mode()[0], inplace=True)

# Drop 'deck' due to too many missing values
df.drop(columns=['deck'], inplace=True)

# Drop rows where 'embark_town' or 'embarked' is still missing (if any)
df.dropna(subset=['embark_town', 'embarked'], inplace=True)
# Out:
# Missing values before cleaning:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64
#
# Missing values after cleaning:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
# Drop duplicate rows
df.drop_duplicates(inplace=True)

# %%
# Convert 'sex', 'embarked', 'class', and 'who' to category type
categorical_columns = ['sex', 'embarked', 'class', 'who']
for col in categorical_columns:
    df[col] = df[col].astype('category')

# %%
# If 'name' column exists, extract titles
if 'name' in df.columns:
    df['Title'] = df['name'].str.extract(r' ([A-Za-z]+)\.', expand=False)
    df['Title'] = df['Title'].replace(['Mlle', 'Ms'], 'Miss')
    df['Title'] = df['Title'].replace(['Mme', 'Lady', 'Countess'], 'Mrs')
    df['Title'] = df['Title'].replace(['Capt', 'Col', 'Major', 'Dr', 'Rev', 'Sir', 'Don', 'Jonkheer'], 'Rare')

# %%
# Create age bins
df['age_group'] = pd.cut(df['age'], bins=[0, 12, 18, 35, 60, 100], labels=['Child', 'Teen', 'Young Adult', 'Adult', 'Senior'])

# %%
# One-hot encoding for 'sex', 'embarked', 'class', 'age_group'
df = pd.get_dummies(df, columns=['sex', 'embarked', 'class', 'age_group'], drop_first=True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df['fare_scaled'] = scaler.fit_transform(df[['fare']])

# %%
# Display cleaned data
df.head()
# Out:
#    survived  pclass   age  sibsp  parch     fare    who  adult_male  \
# 0         0       3  22.0      1      0   7.2500    man        True
# 1         1       1  38.0      1      0  71.2833  woman       False
# 2         1       3  26.0      0      0   7.9250  woman       False
# 3         1       1  35.0      1      0  53.1000  woman       False
# 4         0       3  35.0      0      0   8.0500    man        True
#
#    embark_town alive  ...  sex_male  embarked_Q  embarked_S  class_Second  \
# 0  Southampton    no  ...      True       False        True         False
# 1    Cherbourg   yes  ...     False       False       False         False
# 2  Southampton   yes  ...     False       False        True         False
# 3  Southampton   yes  ...     False       False        True         False
# 4  Southampton    no  ...      True       False        True         False
#
#    class_Third  age_group_Teen  age_group_Young Adult  age_group_Adult  \
# ...
